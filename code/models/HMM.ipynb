# %%
import torch
import torch.nn as nn
import re
import numpy as np
import json
import os
from sklearn.decomposition import PCA
from torch.utils.data import Dataset, DataLoader,TensorDataset
from torch.utils.tensorboard import SummaryWriter
# from google.colab import drive
# drive.mount('/content/drive')

      
target_dim = 256  # 降到 256 维
pca = PCA(n_components=target_dim)

# %%
def split_get_label_from_filename(filename):
    return label_mapping.get(filename[8:-5],-1)

def get_label_from_filename(filename):
    match = re.search(r'_(\d+_?\d*)\.json$', filename)
    print(match)
    if match:
        label_key = match.group(1)
        return label_mapping.get(label_key, -1)  # 如果标签不匹配返回 -1

# 获取文件夹中的文件及其标签
def load_files_and_labels(folder_path,split=False):
    file_list = []
    labels = []
    for file in os.listdir(folder_path):
        # print("file: ", file)
        if file.endswith(".json"):
            if split:
                label = split_get_label_from_filename(file)
            else: label = get_label_from_filename(file)
            if label != -1:
                file_list.append(os.path.join(folder_path, file))
                labels.append(label)
            #print(f"File: {file}, Label: {label}")

    return file_list, labels

# %%
import json
import numpy as np

# 1. 提取字符并编码为整数索引
def hex_to_sequence(hex_feature):
    """
    将十六进制字符串转换为整数索引序列。
    去掉冒号并转换为字符对应的索引。
    """
    hex_chars = hex_feature.replace(":", "")
    char_to_index = {char: idx for idx, char in enumerate("0123456789abcdef")}
    return [char_to_index[char] for char in hex_chars]

def process_json(file_path):
    """
    处理 JSON 文件，提取时间戳、包长度和 raw data 特征，并对特征进行归一化。
    """
    features = []
    try:
        # 打开 JSON 文件
        with open(file_path, 'r', encoding='utf-8') as file:
            datas = json.load(file)

        # 遍历 JSON 数据，提取时间戳和包长度
        initial_timestamp = None
        pre_time=None
        for data in datas:
            try:
                timestamp = float(data["_source"]["layers"]["frame"]["frame.time_relative"])  # 时间戳
                packet_length = int(data["_source"]["layers"]["frame"]["frame.len"])  # 包长度

                # 获取数据部分，若不存在则为0
                if 'data' in data["_source"]["layers"]:
                    rawdata = data["_source"]["layers"]["data"]["data.data"]
                else:
                    rawdata = '0'

                # 将原始数据转换为整数序列
                data_feature = hex_to_sequence(rawdata)

                # 将数据填充或截断为指定长度 2832
                if len(data_feature) < 2832:  # 如果长度小于 2832，填充 0
                    data_feature += [0] * (2832 - len(data_feature))
                elif len(data_feature) > 2832:  # 如果长度大于 2832，截断
                    data_feature = data_feature[:2832]

                # 如果数据长度不符合预期，打印出来
                if len(data_feature) != 2832:
                    print(f"Data feature length mismatch: {len(data_feature)}")

                # 初始化时间戳
                if initial_timestamp is None:
                    initial_timestamp = timestamp  # 设置初始时间戳

                # 计算相对时间戳
                relative_timestamp = timestamp - initial_timestamp
                # print(type(relative_timestamp))

                timestamp_array = np.array([relative_timestamp], dtype=float)
                packet_length_array = np.array([packet_length], dtype=float)/1512
                data_feature = np.array(data_feature, dtype=float)/15
          

                # 对每个特征矩阵进行降维
                # reduced_features_list = []
                # for feature in features_list:
                if pre_time ==None:
                    pre_time=relative_timestamp

                time_diff=relative_timestamp-pre_time
                pre_time=relative_timestamp

                # print(type(relative_timestamp))

                
                timestamp_array = np.array([relative_timestamp], dtype=float)
                
                time_diff_array = np.array([time_diff], dtype=float)
                # print("pca1")
                # # reduced_data_feature = pca.fit_transform(data_feature)  # 对特征维度进行降维
                # print("pca2")
                    # reduced_features_list.append(reduced_feature)
                


                # 将特征按顺序组合为 [时间戳, 包长度, 数据特征]
                feature = np.hstack((timestamp_array, time_diff_array,packet_length_array,data_feature))#,reduced_data_feature

                # 添加到特征列表
                features.append(feature)

            except (KeyError, ValueError) as e:
                # 跳过有问题的数据包
                print(f"Skipping packet due to error: {e}")
                continue
        features_array=np.array(features)
        max_timestamp = np.max(features_array[:, 0])  # 获取最大时间戳
        max_time_diff = np.max(features_array[:, 1])  # 获取最大时间diff
        # print("max")
        features_array[:, 0] = [feature[0] / max_timestamp for feature in features_array]  # 时间戳归一化
        features_array[:, 1] = [feature[1] / max_time_diff for feature in features_array]  # 时间diff归一化
        
        # features_array=np.array(features)
        # max_timestamp = np.max(features_array[:, 0])  # 获取最大时间戳
        # # print("max")
        # features_array[:, 0] = [feature[0] / max_timestamp for feature in features_array]  # 时间戳归一化
        # print("11")

    except Exception as e:
        print(Exception)
        print(f"Error processing file {file_path}: {e}")
        features_array = np.zeros((1, 2835))  # 返回空特征以避免程序中断

    return features_array

# %%
import nest_asyncio
nest_asyncio.apply()


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# 定义文件夹路径 /content/drive/MyDrive/202_project/202_packet_json

split = 2 # 0:100, 1:300, 2:800
# folder_path = "packet_json_split"
if split==1:
    folder_path = "packet_json_split"
elif split==2:
    folder_path = "202_packet_json_new_800"
else:
    folder_path = "202_packet_json_new"

# 定义标签映射
label_mapping = {
    "0": 0,             # static
    "0_2": 1,           # slightly_move
    "1": 2,             # move
    "4": 3              # intensely_move
}

# 调用函数获取文件和标签
data_paths, labels = load_files_and_labels(folder_path,split)
# 用于存储每个样本的特征

print(type(labels))
labels_array=np.array(labels)#[:50]
print(labels_array.shape)
print(labels_array)
labels_tensor=torch.tensor(labels_array,dtype=torch.long)
# Out:
# Using device: cuda
# <class 'list'>
# (800,)
# [1 0 2 2 1 3 1 3 1 1 2 1 0 0 3 0 0 0 2 0 2 3 2 3 0 3 0 3 3 0 0 1 2 1 3 1 2
#  0 2 1 3 3 0 0 2 2 2 3 0 3 3 1 2 1 1 3 0 0 3 3 2 0 1 1 1 0 0 3 0 1 3 2 3 3
#  1 1 0 2 0 2 3 1 3 0 1 0 0 3 1 3 3 0 1 3 1 1 2 0 3 3 1 1 0 0 1 0 3 3 2 0 2
#  2 2 3 0 3 2 3 0 3 1 0 0 3 2 0 0 0 0 2 0 3 0 2 3 3 1 0 3 0 1 2 1 2 0 2 0 3
#  0 1 1 0 2 1 3 0 0 0 3 2 1 1 2 3 3 0 1 3 1 3 3 3 2 1 1 2 3 2 1 1 1 2 2 0 0
#  0 1 2 2 2 2 0 1 2 1 1 1 2 3 0 1 0 2 3 2 2 0 2 1 1 3 0 3 2 2 1 2 3 0 2 3 0
#  1 1 0 3 2 1 3 1 2 3 2 1 3 1 0 0 1 3 1 1 2 0 3 3 1 3 3 0 3 3 3 0 2 2 1 1 0
#  3 2 2 3 3 2 1 1 2 2 1 3 3 3 0 0 3 0 2 3 0 2 0 2 0 2 2 0 0 0 2 2 1 2 0 0 2
#  3 3 3 1 0 2 2 0 2 1 3 0 0 1 3 0 3 1 0 0 1 0 2 2 2 2 3 2 3 3 2 1 2 1 3 3 1
#  1 3 1 1 2 1 1 1 3 0 3 0 3 0 0 2 2 0 3 1 1 0 1 1 0 3 0 0 3 3 0 1 0 1 0 3 3
#  0 0 1 1 0 0 2 0 3 1 3 3 3 0 0 2 2 2 2 1 2 2 0 1 0 2 1 1 3 0 2 2 2 2 3 1 1
#  1 2 3 1 1 2 1 2 3 0 3 3 3 1 3 2 2 1 1 1 2 2 1 2 2 0 0 0 3 2 3 0 0 2 1 3 3
#  3 2 3 0 3 3 1 2 2 0 0 0 0 0 3 2 1 0 0 0 2 0 3 2 1 0 1 3 2 2 2 3 3 0 1 3 2
#  3 0 2 1 0 3 3 3 1 1 3 2 3 3 0 0 3 2 1 0 2 1 1 0 1 3 3 2 1 2 1 1 2 2 2 2 2
#  1 2 3 2 2 1 1 3 1 2 1 0 0 3 3 0 1 2 0 0 3 2 0 2 2 0 3 1 2 1 1 3 1 3 3 0 1
#  2 2 1 1 1 2 3 2 0 1 2 2 3 2 2 3 1 0 1 1 2 1 3 1 2 1 2 0 0 3 3 1 0 0 3 3 0
#  3 3 3 2 2 1 2 2 1 1 2 1 1 1 0 3 2 3 3 2 0 0 2 0 3 3 1 3 1 1 2 1 1 3 2 3 1
#  1 1 0 3 0 3 0 2 1 2 1 3 2 3 2 1 0 2 3 2 1 0 3 1 3 0 1 2 0 2 2 0 3 0 1 1 2
#  2 2 0 2 0 1 2 1 1 0 3 2 3 1 0 2 0 2 2 0 0 2 2 1 2 2 0 3 2 0 1 1 2 2 1 3 0
#  3 1 3 3 0 0 1 3 3 0 0 0 1 2 1 0 3 1 0 0 1 1 1 1 1 0 2 3 3 2 2 3 0 0 1 1 3
#  1 1 0 2 2 0 1 3 2 3 3 3 2 3 0 0 3 2 1 3 1 0 3 1 1 2 0 0 1 0 2 0 1 3 2 0 0
#  2 3 3 3 0 2 3 2 3 1 2 3 0 1 1 2 0 3 1 3 0 0 0]

# %%
      
# target_dim = 256  # 降到 256 维
# pca = PCA(n_components=target_dim)

features_list = []
for data_path in data_paths:
  # count +=1
  print(data_path)
  features = process_json(data_path)
  features_list.append(features)
  print(features.shape)
print(f"生成了 {len(features_list)} 个样本特征")
print(f"第一个样本的特征形状: {features_list[0].shape}")
# Out:
# 202_packet_json_new_800/b1_p5_5_0_2.json
# (1486, 2835)
# 202_packet_json_new_800/b4_p3_7_0.json
# (1662, 2835)
# 202_packet_json_new_800/b2_p3_8_1.json
# (618, 2835)
# 202_packet_json_new_800/b3_p2_2_1.json
# (1700, 2835)
# 202_packet_json_new_800/b5_p4_6_0_2.json
# (1663, 2835)
# 202_packet_json_new_800/b3_p5_4_4.json
# (1518, 2835)
# 202_packet_json_new_800/b1_p3_2_0_2.json
# (1304, 2835)
# 202_packet_json_new_800/b1_p4_4_4.json
# (1385, 2835)
# 202_packet_json_new_800/b1_p1_2_0_2.json
# (1692, 2835)
# 202_packet_json_new_800/b3_p3_3_0_2.json
# (1567, 2835)
# 202_packet_json_new_800/b1_p1_2_1.json
# (1457, 2835)
# 202_packet_json_new_800/b2_p2_2_0_2.json
# (1582, 2835)
# 202_packet_json_new_800/b3_p1_2_0.json
# (1743, 2835)
# 202_packet_json_new_800/b1_p2_8_0.json
# (1341, 2835)
# 202_packet_json_new_800/b5_p4_3_4.json
# (1781, 2835)
# 202_packet_json_new_800/b3_p2_6_0.json
# (1736, 2835)
# 202_packet_json_new_800/b5_p1_7_0.json
# (1621, 2835)
# 202_packet_json_new_800/b4_p1_3_0.json
# (1727, 2835)
# 202_packet_json_new_800/b1_p3_2_1.json
# (1291, 2835)
# 202_packet_json_new_800/b5_p2_7_0.json
# (1725, 2835)
# 202_packet_json_new_800/b2_p5_1_1.json
# (2192, 2835)
# 202_packet_json_new_800/b4_p4_7_4.json
# (1509, 2835)
# 202_packet_json_new_800/b5_p4_1_1.json
# (1730, 2835)
# 202_packet_json_new_800/b3_p3_5_4.json
# (1684, 2835)
# 202_packet_json_new_800/b3_p5_1_0.json
# (1734, 2835)
# 202_packet_json_new_800/b1_p5_1_4.json
# (1449, 2835)
# 202_packet_json_new_800/b3_p3_1_0.json
# (1746, 2835)
# 202_packet_json_new_800/b1_p5_8_4.json
# (1467, 2835)
# 202_packet_json_new_800/b1_p3_2_4.json
# (1442, 2835)
# 202_packet_json_new_800/b3_p3_2_0.json
# (1593, 2835)
# 202_packet_json_new_800/b2_p3_7_0.json
# (1560, 2835)
# 202_packet_json_new_800/b3_p4_8_0_2.json
# (1516, 2835)
# 202_packet_json_new_800/b5_p4_3_1.json
# (1639, 2835)
# 202_packet_json_new_800/b2_p5_2_0_2.json
# (1591, 2835)
# 202_packet_json_new_800/b4_p4_8_4.json
# (1611, 2835)
# 202_packet_json_new_800/b2_p1_4_0_2.json
# (1802, 2835)
# 202_packet_json_new_800/b1_p3_1_1.json
# (1288, 2835)
# 202_packet_json_new_800/b2_p3_6_0.json
# (1692, 2835)
# 202_packet_json_new_800/b2_p2_6_1.json
# (1870, 2835)
# 202_packet_json_new_800/b3_p5_6_0_2.json
# (1835, 2835)
# 202_packet_json_new_800/b2_p4_8_4.json
# (1419, 2835)
# 202_packet_json_new_800/b3_p1_1_4.json
# (1706, 2835)
# 202_packet_json_new_800/b2_p1_1_0.json
# (1504, 2835)
# 202_packet_json_new_800/b1_p1_8_0.json
# (1406, 2835)
# 202_packet_json_new_800/b2_p3_4_1.json
# (1721, 2835)
# 202_packet_json_new_800/b2_p5_4_1.json
# (1794, 2835)
# 202_packet_json_new_800/b3_p5_7_1.json
# (1379, 2835)
# 202_packet_json_new_800/b3_p5_1_4.json
# (1360, 2835)
# 202_packet_json_new_800/b1_p1_2_0.json
# (1535, 2835)
# 202_packet_json_new_800/b1_p5_2_4.json
# (1624, 2835)
# 202_packet_json_new_800/b5_p1_5_4.json
# (1655, 2835)
# 202_packet_json_new_800/b3_p4_4_0_2.json
# (1630, 2835)
# 202_packet_json_new_800/b4_p4_2_1.json
# (1579, 2835)
# 202_packet_json_new_800/b3_p3_8_0_2.json
# (1600, 2835)
# 202_packet_json_new_800/b2_p3_8_0_2.json
# (1716, 2835)
# 202_packet_json_new_800/b5_p5_4_4.json
# (1512, 2835)
# 202_packet_json_new_800/b3_p1_8_0.json
# (1646, 2835)
# 202_packet_json_new_800/b3_p5_5_0.json
# (1871, 2835)
# 202_packet_json_new_800/b1_p5_6_4.json
# (1679, 2835)
# 202_packet_json_new_800/b4_p2_4_4.json
# (1664, 2835)
# 202_packet_json_new_800/b5_p5_6_1.json
# (1597, 2835)
# 202_packet_json_new_800/b4_p3_4_0.json
# (1877, 2835)
# 202_packet_json_new_800/b1_p4_6_0_2.json
# (1457, 2835)
# 202_packet_json_new_800/b2_p3_1_0_2.json
# (1492, 2835)
# 202_packet_json_new_800/b5_p5_8_0_2.json
# (1470, 2835)
# 202_packet_json_new_800/b1_p1_3_0.json
# (1649, 2835)
# 202_packet_json_new_800/b1_p4_3_0.json
# (1451, 2835)
# 202_packet_json_new_800/b2_p1_8_4.json
# (1587, 2835)
# 202_packet_json_new_800/b4_p3_6_0.json
# (1540, 2835)
# 202_packet_json_new_800/b3_p3_4_0_2.json
# (1923, 2835)
# 202_packet_json_new_800/b5_p5_2_4.json
# (1572, 2835)
# 202_packet_json_new_800/b5_p4_2_1.json
# (1781, 2835)
# 202_packet_json_new_800/b4_p4_3_4.json
# (1518, 2835)
# 202_packet_json_new_800/b1_p5_7_4.json
# (1394, 2835)
# 202_packet_json_new_800/b3_p2_5_0_2.json
# (1552, 2835)
# 202_packet_json_new_800/b5_p5_1_0_2.json
# (2478, 2835)
# 202_packet_json_new_800/b2_p3_4_0.json
# (1777, 2835)
# 202_packet_json_new_800/b1_p3_4_1.json
# (1271, 2835)
# 202_packet_json_new_800/b3_p3_4_0.json
# (1777, 2835)
# 202_packet_json_new_800/b5_p2_7_1.json
# (1518, 2835)
# 202_packet_json_new_800/b5_p4_4_4.json
# (1612, 2835)
# 202_packet_json_new_800/b3_p3_1_0_2.json
# (1989, 2835)
# 202_packet_json_new_800/b5_p3_1_4.json
# (1638, 2835)
# 202_packet_json_new_800/b2_p1_5_0.json
# (1466, 2835)
# 202_packet_json_new_800/b3_p5_7_0_2.json
# (1641, 2835)
# 202_packet_json_new_800/b2_p4_5_0.json
# (2064, 2835)
# 202_packet_json_new_800/b4_p2_4_0.json
# (1637, 2835)
# 202_packet_json_new_800/b4_p1_1_4.json
# (1603, 2835)
# 202_packet_json_new_800/b2_p1_7_0_2.json
# (1618, 2835)
# 202_packet_json_new_800/b2_p4_3_4.json
# (1726, 2835)
# 202_packet_json_new_800/b4_p5_6_4.json
# (1666, 2835)
# 202_packet_json_new_800/b1_p1_7_0.json
# (1588, 2835)
# 202_packet_json_new_800/b3_p5_3_0_2.json
# (1883, 2835)
# 202_packet_json_new_800/b4_p4_6_4.json
# (1569, 2835)
# 202_packet_json_new_800/b1_p5_7_0_2.json
# (1509, 2835)
# 202_packet_json_new_800/b1_p5_2_0_2.json
# (1591, 2835)
# 202_packet_json_new_800/b4_p5_1_1.json
# (1510, 2835)
# 202_packet_json_new_800/b4_p2_5_0.json
# (1495, 2835)
# 202_packet_json_new_800/b2_p1_3_4.json
# (1554, 2835)
# 202_packet_json_new_800/b5_p2_4_4.json
# (1806, 2835)
# 202_packet_json_new_800/b3_p2_3_0_2.json
# (1575, 2835)
# 202_packet_json_new_800/b1_p1_8_0_2.json
# (1498, 2835)
# 202_packet_json_new_800/b2_p3_8_0.json
# (1525, 2835)
# 202_packet_json_new_800/b1_p1_4_0.json
# (1386, 2835)
# 202_packet_json_new_800/b5_p1_4_0_2.json
# (1605, 2835)
# 202_packet_json_new_800/b3_p1_5_0.json
# (1687, 2835)
# 202_packet_json_new_800/b3_p4_5_4.json
# (1748, 2835)
# 202_packet_json_new_800/b2_p2_7_4.json
# (1661, 2835)
# 202_packet_json_new_800/b3_p2_7_1.json
# (1389, 2835)
# 202_packet_json_new_800/b1_p2_7_0.json
# (1393, 2835)
# 202_packet_json_new_800/b4_p5_3_1.json
# (1613, 2835)
# 202_packet_json_new_800/b4_p4_4_1.json
# (1708, 2835)
# 202_packet_json_new_800/b4_p1_5_1.json
# (1601, 2835)
# 202_packet_json_new_800/b5_p4_6_4.json
# (1679, 2835)
# 202_packet_json_new_800/b4_p1_8_0.json
# (1301, 2835)
# 202_packet_json_new_800/b2_p2_2_4.json
# (1730, 2835)
# 202_packet_json_new_800/b1_p5_5_1.json
# (1514, 2835)
# 202_packet_json_new_800/b1_p4_5_4.json
# (1373, 2835)
# 202_packet_json_new_800/b5_p3_5_0.json
# (1658, 2835)
# 202_packet_json_new_800/b5_p4_5_4.json
# (1701, 2835)
# 202_packet_json_new_800/b3_p1_4_0_2.json
# (1739, 2835)
# 202_packet_json_new_800/b1_p3_6_0.json
# (1446, 2835)
# 202_packet_json_new_800/b5_p1_2_0.json
# (1473, 2835)
# 202_packet_json_new_800/b5_p3_6_4.json
# (1564, 2835)
# 202_packet_json_new_800/b1_p1_3_1.json
# (1463, 2835)
# 202_packet_json_new_800/b4_p3_8_0.json
# (1369, 2835)
# 202_packet_json_new_800/b3_p4_1_0.json
# (1894, 2835)
# 202_packet_json_new_800/b4_p3_1_0.json
# (1785, 2835)
# 202_packet_json_new_800/b3_p3_5_0.json
# (1709, 2835)
# 202_packet_json_new_800/b3_p1_3_1.json
# (1514, 2835)
# 202_packet_json_new_800/b5_p2_5_0.json
# (1563, 2835)
# 202_packet_json_new_800/b1_p3_1_4.json
# (1399, 2835)
# 202_packet_json_new_800/b5_p5_5_0.json
# (1632, 2835)
# 202_packet_json_new_800/b2_p5_7_1.json
# (1787, 2835)
# 202_packet_json_new_800/b4_p5_3_4.json
# (1599, 2835)
# 202_packet_json_new_800/b4_p5_8_4.json
# (1457, 2835)
# 202_packet_json_new_800/b4_p4_6_0_2.json
# (1659, 2835)
# 202_packet_json_new_800/b4_p5_5_0.json
# (1786, 2835)
# 202_packet_json_new_800/b4_p3_4_4.json
# (1669, 2835)
# 202_packet_json_new_800/b4_p1_4_0.json
# (1688, 2835)
# 202_packet_json_new_800/b5_p5_4_0_2.json
# (1588, 2835)
# 202_packet_json_new_800/b2_p1_2_1.json
# (1710, 2835)
# 202_packet_json_new_800/b3_p4_2_0_2.json
# (1604, 2835)
# 202_packet_json_new_800/b2_p5_3_1.json
# (1659, 2835)
# 202_packet_json_new_800/b2_p4_3_0.json
# (1622, 2835)
# 202_packet_json_new_800/b3_p4_7_1.json
# (1571, 2835)
# 202_packet_json_new_800/b5_p2_4_0.json
# (1610, 2835)
# 202_packet_json_new_800/b1_p1_7_4.json
# (1494, 2835)
# 202_packet_json_new_800/b5_p3_7_0.json
# (1529, 2835)
# 202_packet_json_new_800/b4_p1_2_0_2.json
# (1518, 2835)
# 202_packet_json_new_800/b5_p5_5_0_2.json
# (1708, 2835)
# 202_packet_json_new_800/b2_p2_2_0.json
# (1853, 2835)
# 202_packet_json_new_800/b1_p5_2_1.json
# (1342, 2835)
# 202_packet_json_new_800/b1_p1_6_0_2.json
# (1627, 2835)
# 202_packet_json_new_800/b5_p3_4_4.json
# (1523, 2835)
# 202_packet_json_new_800/b5_p3_2_0.json
# (1560, 2835)
# 202_packet_json_new_800/b4_p4_1_0.json
# (1695, 2835)
# 202_packet_json_new_800/b4_p2_7_0.json
# (1390, 2835)
# 202_packet_json_new_800/b2_p4_2_4.json
# (1496, 2835)
# 202_packet_json_new_800/b5_p5_7_1.json
# (1676, 2835)
# 202_packet_json_new_800/b4_p1_6_0_2.json
# (1528, 2835)
# 202_packet_json_new_800/b1_p2_6_0_2.json
# (1484, 2835)
# 202_packet_json_new_800/b3_p5_8_1.json
# (1435, 2835)
# 202_packet_json_new_800/b4_p2_1_4.json
# (1641, 2835)
# 202_packet_json_new_800/b3_p3_8_4.json
# (1501, 2835)
# 202_packet_json_new_800/b4_p5_3_0.json
# (1756, 2835)
# 202_packet_json_new_800/b3_p5_4_0_2.json
# (1573, 2835)
# 202_packet_json_new_800/b5_p2_8_4.json
# (1867, 2835)
# 202_packet_json_new_800/b5_p5_7_0_2.json
# (1649, 2835)
# 202_packet_json_new_800/b3_p4_3_4.json
# (2328, 2835)
# 202_packet_json_new_800/b5_p1_8_4.json
# (1461, 2835)
# 202_packet_json_new_800/b3_p5_3_4.json
# (1390, 2835)
# 202_packet_json_new_800/b4_p2_1_1.json
# (1501, 2835)
# 202_packet_json_new_800/b3_p1_5_0_2.json
# (1818, 2835)
# 202_packet_json_new_800/b2_p2_1_0_2.json
# (1731, 2835)
# 202_packet_json_new_800/b2_p4_5_1.json
# (1698, 2835)
# 202_packet_json_new_800/b2_p1_2_4.json
# (1556, 2835)
# 202_packet_json_new_800/b2_p5_2_1.json
# (2051, 2835)
# 202_packet_json_new_800/b5_p1_2_0_2.json
# (1723, 2835)
# 202_packet_json_new_800/b4_p5_8_0_2.json
# (1408, 2835)
# 202_packet_json_new_800/b2_p2_7_0_2.json
# (1777, 2835)
# 202_packet_json_new_800/b2_p5_5_1.json
# (1547, 2835)
# 202_packet_json_new_800/b5_p2_3_1.json
# (1397, 2835)
# 202_packet_json_new_800/b5_p5_6_0.json
# (1593, 2835)
# 202_packet_json_new_800/b5_p3_1_0.json
# (1422, 2835)
# 202_packet_json_new_800/b3_p5_7_0.json
# (1724, 2835)
# 202_packet_json_new_800/b1_p2_4_0_2.json
# (1432, 2835)
# 202_packet_json_new_800/b1_p5_3_1.json
# (1489, 2835)
# 202_packet_json_new_800/b3_p3_8_1.json
# (1423, 2835)
# 202_packet_json_new_800/b5_p1_1_1.json
# (1839, 2835)
# 202_packet_json_new_800/b2_p2_3_1.json
# (1773, 2835)
# 202_packet_json_new_800/b2_p5_6_0.json
# (1679, 2835)
# 202_packet_json_new_800/b1_p4_1_0_2.json
# (1410, 2835)
# 202_packet_json_new_800/b3_p3_2_1.json
# (1554, 2835)
# 202_packet_json_new_800/b1_p3_4_0_2.json
# (1401, 2835)
# 202_packet_json_new_800/b4_p1_3_0_2.json
# (1544, 2835)
# 202_packet_json_new_800/b4_p1_5_0_2.json
# (1729, 2835)
# 202_packet_json_new_800/b2_p1_8_1.json
# (1732, 2835)
# 202_packet_json_new_800/b1_p2_1_4.json
# (1379, 2835)
# 202_packet_json_new_800/b5_p4_3_0.json
# (1038, 2835)
# 202_packet_json_new_800/b4_p1_7_0_2.json
# (1555, 2835)
# 202_packet_json_new_800/b5_p1_4_0.json
# (1454, 2835)
# 202_packet_json_new_800/b4_p2_4_1.json
# (1445, 2835)
# 202_packet_json_new_800/b2_p3_2_4.json
# (1711, 2835)
# 202_packet_json_new_800/b2_p1_3_1.json
# (1959, 2835)
# 202_packet_json_new_800/b5_p1_5_1.json
# (1589, 2835)
# 202_packet_json_new_800/b4_p3_5_0.json
# (1718, 2835)
# 202_packet_json_new_800/b3_p1_4_1.json
# (1926, 2835)
# 202_packet_json_new_800/b1_p1_3_0_2.json
# (1587, 2835)
# 202_packet_json_new_800/b5_p3_6_0_2.json
# (1597, 2835)
# 202_packet_json_new_800/b5_p5_5_4.json
# (1503, 2835)
# 202_packet_json_new_800/b4_p4_6_0.json
# (1646, 2835)
# 202_packet_json_new_800/b5_p2_5_4.json
# (1741, 2835)
# 202_packet_json_new_800/b4_p1_1_1.json
# (1875, 2835)
# 202_packet_json_new_800/b4_p3_1_1.json
# (1734, 2835)
# 202_packet_json_new_800/b5_p1_1_0_2.json
# (1755, 2835)
# 202_packet_json_new_800/b1_p4_1_1.json
# (1373, 2835)
# 202_packet_json_new_800/b5_p4_8_4.json
# (1378, 2835)
# 202_packet_json_new_800/b5_p3_3_0.json
# (1515, 2835)
# 202_packet_json_new_800/b1_p1_8_1.json
# (1504, 2835)
# 202_packet_json_new_800/b5_p1_6_4.json
# (1535, 2835)
# 202_packet_json_new_800/b2_p5_1_0.json
# (1657, 2835)
# 202_packet_json_new_800/b5_p3_5_0_2.json
# (1493, 2835)
# 202_packet_json_new_800/b4_p4_7_0_2.json
# (1595, 2835)
# 202_packet_json_new_800/b1_p5_3_0.json
# (1523, 2835)
# 202_packet_json_new_800/b4_p5_1_4.json
# (1744, 2835)
# 202_packet_json_new_800/b2_p4_3_1.json
# (1705, 2835)
# 202_packet_json_new_800/b4_p5_6_0_2.json
# (1626, 2835)
# 202_packet_json_new_800/b1_p5_3_4.json
# (1457, 2835)
# 202_packet_json_new_800/b3_p2_4_0_2.json
# (1487, 2835)
# 202_packet_json_new_800/b4_p4_1_1.json
# (1569, 2835)
# 202_packet_json_new_800/b4_p5_4_4.json
# (1512, 2835)
# 202_packet_json_new_800/b5_p2_1_1.json
# (1476, 2835)
# 202_packet_json_new_800/b1_p4_8_0_2.json
# (1479, 2835)
# 202_packet_json_new_800/b5_p4_7_4.json
# (1752, 2835)
# 202_packet_json_new_800/b3_p3_5_0_2.json
# (1645, 2835)
# 202_packet_json_new_800/b5_p5_8_0.json
# (1466, 2835)
# 202_packet_json_new_800/b5_p4_7_0.json
# (1718, 2835)
# 202_packet_json_new_800/b5_p4_3_0_2.json
# (1448, 2835)
# 202_packet_json_new_800/b5_p5_1_4.json
# (1613, 2835)
# 202_packet_json_new_800/b2_p5_3_0_2.json
# (1610, 2835)
# 202_packet_json_new_800/b1_p3_6_0_2.json
# (1399, 2835)
# 202_packet_json_new_800/b2_p3_6_1.json
# (1758, 2835)
# 202_packet_json_new_800/b1_p5_8_0.json
# (1625, 2835)
# 202_packet_json_new_800/b4_p2_6_4.json
# (1671, 2835)
# 202_packet_json_new_800/b5_p5_6_4.json
# (1448, 2835)
# 202_packet_json_new_800/b1_p1_4_0_2.json
# (1563, 2835)
# 202_packet_json_new_800/b2_p1_4_4.json
# (1667, 2835)
# 202_packet_json_new_800/b5_p1_7_4.json
# (1584, 2835)
# 202_packet_json_new_800/b2_p3_1_0.json
# (1746, 2835)
# 202_packet_json_new_800/b1_p2_4_4.json
# (1549, 2835)
# 202_packet_json_new_800/b5_p5_3_4.json
# (1523, 2835)
# 202_packet_json_new_800/b3_p1_5_4.json
# (1466, 2835)
# 202_packet_json_new_800/b5_p1_1_0.json
# (1659, 2835)
# 202_packet_json_new_800/b4_p1_7_1.json
# (1528, 2835)
# 202_packet_json_new_800/b3_p4_5_1.json
# (1637, 2835)
# 202_packet_json_new_800/b4_p5_1_0_2.json
# (1501, 2835)
# 202_packet_json_new_800/b5_p4_5_0_2.json
# (1498, 2835)
# 202_packet_json_new_800/b3_p1_1_0.json
# (1742, 2835)
# 202_packet_json_new_800/b3_p1_7_4.json
# (1799, 2835)
# 202_packet_json_new_800/b4_p2_7_1.json
# (1559, 2835)
# 202_packet_json_new_800/b2_p1_5_1.json
# (1603, 2835)
# 202_packet_json_new_800/b3_p4_4_4.json
# (1677, 2835)
# 202_packet_json_new_800/b2_p3_8_4.json
# (1696, 2835)
# 202_packet_json_new_800/b1_p1_1_1.json
# (1453, 2835)
# 202_packet_json_new_800/b5_p1_5_0_2.json
# (1542, 2835)
# 202_packet_json_new_800/b2_p4_6_0_2.json
# (1773, 2835)
# 202_packet_json_new_800/b2_p1_7_1.json
# (2034, 2835)
# 202_packet_json_new_800/b1_p4_3_1.json
# (1377, 2835)
# 202_packet_json_new_800/b5_p2_5_0_2.json
# (1498, 2835)
# 202_packet_json_new_800/b2_p3_7_4.json
# (1920, 2835)
# 202_packet_json_new_800/b4_p3_7_4.json
# (1604, 2835)
# 202_packet_json_new_800/b3_p2_1_4.json
# (1756, 2835)
# 202_packet_json_new_800/b4_p1_6_0.json
# (1685, 2835)
# 202_packet_json_new_800/b1_p2_4_0.json
# (1554, 2835)
# 202_packet_json_new_800/b1_p4_2_4.json
# (1307, 2835)
# 202_packet_json_new_800/b3_p2_1_0.json
# (1609, 2835)
# 202_packet_json_new_800/b4_p5_2_1.json
# (1647, 2835)
# 202_packet_json_new_800/b2_p1_5_4.json
# (1473, 2835)
# 202_packet_json_new_800/b4_p4_2_0.json
# (1412, 2835)
# 202_packet_json_new_800/b5_p1_7_1.json
# (1587, 2835)
# 202_packet_json_new_800/b5_p5_2_0.json
# (1710, 2835)
# 202_packet_json_new_800/b1_p2_3_1.json
# (1305, 2835)
# 202_packet_json_new_800/b3_p5_2_0.json
# (1656, 2835)
# 202_packet_json_new_800/b1_p2_8_1.json
# (1106, 2835)
# 202_packet_json_new_800/b1_p4_4_1.json
# (1579, 2835)
# 202_packet_json_new_800/b5_p1_8_0.json
# (1304, 2835)
# 202_packet_json_new_800/b5_p4_2_0.json
# (1508, 2835)
# 202_packet_json_new_800/b2_p5_8_0.json
# (1427, 2835)
# 202_packet_json_new_800/b4_p3_6_1.json
# (1558, 2835)
# 202_packet_json_new_800/b4_p4_5_1.json
# (1606, 2835)
# 202_packet_json_new_800/b4_p3_2_0_2.json
# (1565, 2835)
# 202_packet_json_new_800/b2_p4_6_1.json
# (1859, 2835)
# 202_packet_json_new_800/b1_p3_8_0.json
# (1274, 2835)
# 202_packet_json_new_800/b2_p3_3_0.json
# (1595, 2835)
# 202_packet_json_new_800/b4_p3_2_1.json
# (1577, 2835)
# 202_packet_json_new_800/b2_p5_6_4.json
# (1660, 2835)
# 202_packet_json_new_800/b5_p4_2_4.json
# (1591, 2835)
# 202_packet_json_new_800/b3_p5_5_4.json
# (1422, 2835)
# 202_packet_json_new_800/b3_p4_7_0_2.json
# (1494, 2835)
# 202_packet_json_new_800/b5_p2_8_0.json
# (1339, 2835)
# 202_packet_json_new_800/b5_p5_8_1.json
# (1373, 2835)
# 202_packet_json_new_800/b2_p2_1_1.json
# (1905, 2835)
# 202_packet_json_new_800/b5_p1_3_0.json
# (1540, 2835)
# 202_packet_json_new_800/b5_p1_6_1.json
# (1566, 2835)
# 202_packet_json_new_800/b2_p4_5_0_2.json
# (1983, 2835)
# 202_packet_json_new_800/b4_p2_2_4.json
# (1709, 2835)
# 202_packet_json_new_800/b2_p5_3_0.json
# (1707, 2835)
# 202_packet_json_new_800/b1_p4_7_0.json
# (1470, 2835)
# 202_packet_json_new_800/b2_p4_8_0_2.json
# (1775, 2835)
# 202_packet_json_new_800/b1_p1_8_4.json
# (1391, 2835)
# 202_packet_json_new_800/b4_p5_7_0.json
# (1648, 2835)
# 202_packet_json_new_800/b3_p2_3_4.json
# (1799, 2835)
# 202_packet_json_new_800/b2_p3_2_0_2.json
# (1739, 2835)
# 202_packet_json_new_800/b4_p1_7_0.json
# (1651, 2835)
# 202_packet_json_new_800/b1_p4_6_0.json
# (1411, 2835)
# 202_packet_json_new_800/b2_p3_6_0_2.json
# (1867, 2835)
# 202_packet_json_new_800/b1_p2_6_0.json
# (1604, 2835)
# 202_packet_json_new_800/b5_p3_1_1.json
# (1891, 2835)
# 202_packet_json_new_800/b3_p1_5_1.json
# (1755, 2835)
# 202_packet_json_new_800/b4_p3_7_1.json
# (1726, 2835)
# 202_packet_json_new_800/b3_p3_1_1.json
# (1821, 2835)
# 202_packet_json_new_800/b2_p2_4_4.json
# (1759, 2835)
# 202_packet_json_new_800/b3_p3_4_1.json
# (1753, 2835)
# 202_packet_json_new_800/b5_p2_7_4.json
# (1643, 2835)
# 202_packet_json_new_800/b2_p4_5_4.json
# (1744, 2835)
# 202_packet_json_new_800/b3_p1_7_1.json
# (1678, 2835)
# 202_packet_json_new_800/b2_p2_5_0_2.json
# (1528, 2835)
# 202_packet_json_new_800/b5_p5_5_1.json
# (1665, 2835)
# 202_packet_json_new_800/b3_p1_2_0_2.json
# (1581, 2835)
# 202_packet_json_new_800/b1_p3_5_4.json
# (1573, 2835)
# 202_packet_json_new_800/b3_p4_7_4.json
# (1713, 2835)
# 202_packet_json_new_800/b5_p3_7_0_2.json
# (1511, 2835)
# 202_packet_json_new_800/b4_p3_5_0_2.json
# (1543, 2835)
# 202_packet_json_new_800/b5_p5_7_4.json
# (1603, 2835)
# 202_packet_json_new_800/b1_p2_1_0_2.json
# (1492, 2835)
# 202_packet_json_new_800/b4_p4_8_0_2.json
# (1330, 2835)
# 202_packet_json_new_800/b5_p2_4_1.json
# (1345, 2835)
# 202_packet_json_new_800/b4_p3_4_0_2.json
# (1546, 2835)
# 202_packet_json_new_800/b1_p4_7_0_2.json
# (1596, 2835)
# 202_packet_json_new_800/b2_p3_3_0_2.json
# (1642, 2835)
# 202_packet_json_new_800/b3_p2_5_4.json
# (1769, 2835)
# 202_packet_json_new_800/b3_p3_3_0.json
# (1595, 2835)
# 202_packet_json_new_800/b3_p4_8_4.json
# (1313, 2835)
# 202_packet_json_new_800/b3_p5_3_0.json
# (1896, 2835)
# 202_packet_json_new_800/b1_p3_8_4.json
# (1246, 2835)
# 202_packet_json_new_800/b5_p1_5_0.json
# (1601, 2835)
# 202_packet_json_new_800/b2_p2_5_0.json
# (1609, 2835)
# 202_packet_json_new_800/b1_p1_7_1.json
# (1400, 2835)
# 202_packet_json_new_800/b3_p3_6_1.json
# (1632, 2835)
# 202_packet_json_new_800/b1_p1_6_0.json
# (1391, 2835)
# 202_packet_json_new_800/b5_p4_1_4.json
# (1644, 2835)
# 202_packet_json_new_800/b2_p4_1_0_2.json
# (1776, 2835)
# 202_packet_json_new_800/b5_p2_7_0_2.json
# (1489, 2835)
# 202_packet_json_new_800/b5_p4_6_0.json
# (1825, 2835)
# 202_packet_json_new_800/b1_p1_5_0_2.json
# (1754, 2835)
# 202_packet_json_new_800/b2_p3_7_0_2.json
# (1682, 2835)
# 202_packet_json_new_800/b2_p2_4_0.json
# (1735, 2835)
# 202_packet_json_new_800/b1_p3_7_4.json
# (1492, 2835)
# 202_packet_json_new_800/b2_p3_2_0.json
# (1593, 2835)
# 202_packet_json_new_800/b3_p5_6_0.json
# (1867, 2835)
# 202_packet_json_new_800/b4_p1_3_4.json
# (1620, 2835)
# 202_packet_json_new_800/b2_p4_4_4.json
# (1604, 2835)
# 202_packet_json_new_800/b4_p2_2_0.json
# (1562, 2835)
# 202_packet_json_new_800/b4_p5_4_0_2.json
# (1550, 2835)
# 202_packet_json_new_800/b1_p3_4_0.json
# (1398, 2835)
# 202_packet_json_new_800/b4_p3_7_0_2.json
# (1605, 2835)
# 202_packet_json_new_800/b5_p3_4_0.json
# (1555, 2835)
# 202_packet_json_new_800/b4_p4_4_4.json
# (1624, 2835)
# 202_packet_json_new_800/b2_p2_5_4.json
# (1850, 2835)
# 202_packet_json_new_800/b1_p5_1_0.json
# (1452, 2835)
# 202_packet_json_new_800/b2_p5_7_0.json
# (1844, 2835)
# 202_packet_json_new_800/b4_p4_4_0_2.json
# (1634, 2835)
# 202_packet_json_new_800/b4_p5_2_0_2.json
# (1675, 2835)
# 202_packet_json_new_800/b1_p3_5_0.json
# (1515, 2835)
# 202_packet_json_new_800/b2_p4_4_0.json
# (1605, 2835)
# 202_packet_json_new_800/b5_p4_8_1.json
# (1658, 2835)
# 202_packet_json_new_800/b4_p4_8_0.json
# (1360, 2835)
# 202_packet_json_new_800/b5_p1_3_4.json
# (1631, 2835)
# 202_packet_json_new_800/b2_p1_1_0_2.json
# (1597, 2835)
# 202_packet_json_new_800/b4_p2_5_4.json
# (1710, 2835)
# 202_packet_json_new_800/b4_p3_3_4.json
# (1552, 2835)
# 202_packet_json_new_800/b5_p2_3_4.json
# (1713, 2835)
# 202_packet_json_new_800/b1_p1_5_0.json
# (1517, 2835)
# 202_packet_json_new_800/b4_p3_2_0.json
# (1704, 2835)
# 202_packet_json_new_800/b5_p2_2_1.json
# (1394, 2835)
# 202_packet_json_new_800/b5_p3_8_1.json
# (1690, 2835)
# 202_packet_json_new_800/b4_p1_4_1.json
# (1550, 2835)
# 202_packet_json_new_800/b3_p4_4_1.json
# (1665, 2835)
# 202_packet_json_new_800/b5_p4_2_0_2.json
# (1582, 2835)
# 202_packet_json_new_800/b5_p3_7_1.json
# (1498, 2835)
# 202_packet_json_new_800/b1_p2_7_1.json
# (1337, 2835)
# 202_packet_json_new_800/b5_p5_3_0.json
# (1548, 2835)
# 202_packet_json_new_800/b4_p5_7_0_2.json
# (1423, 2835)
# 202_packet_json_new_800/b3_p5_4_0.json
# (1820, 2835)
# 202_packet_json_new_800/b3_p3_5_1.json
# (1717, 2835)
# 202_packet_json_new_800/b2_p3_5_0_2.json
# (1630, 2835)
# 202_packet_json_new_800/b1_p5_8_0_2.json
# (1524, 2835)
# 202_packet_json_new_800/b3_p3_2_4.json
# (1622, 2835)
# 202_packet_json_new_800/b1_p5_6_0.json
# (1611, 2835)
# 202_packet_json_new_800/b4_p5_8_1.json
# (1494, 2835)
# 202_packet_json_new_800/b2_p3_5_1.json
# (1711, 2835)
# 202_packet_json_new_800/b1_p4_8_1.json
# (1120, 2835)
# 202_packet_json_new_800/b1_p3_7_1.json
# (1449, 2835)
# 202_packet_json_new_800/b1_p4_8_4.json
# (1394, 2835)
# 202_packet_json_new_800/b3_p3_7_0_2.json
# (1782, 2835)
# 202_packet_json_new_800/b1_p2_5_0_2.json
# (1509, 2835)
# 202_packet_json_new_800/b5_p3_2_0_2.json
# (1610, 2835)
# 202_packet_json_new_800/b3_p2_1_1.json
# (1487, 2835)
# 202_packet_json_new_800/b1_p4_1_4.json
# (1349, 2835)
# 202_packet_json_new_800/b2_p4_7_0_2.json
# (1492, 2835)
# 202_packet_json_new_800/b1_p2_3_0_2.json
# (1590, 2835)
# 202_packet_json_new_800/b3_p5_3_1.json
# (1568, 2835)
# 202_packet_json_new_800/b3_p4_6_0_2.json
# (1626, 2835)
# 202_packet_json_new_800/b5_p4_6_1.json
# (1818, 2835)
# 202_packet_json_new_800/b4_p4_1_4.json
# (1740, 2835)
# 202_packet_json_new_800/b5_p2_2_0.json
# (1730, 2835)
# 202_packet_json_new_800/b5_p1_4_4.json
# (1635, 2835)
# 202_packet_json_new_800/b2_p5_5_4.json
# (1651, 2835)
# 202_packet_json_new_800/b2_p4_1_4.json
# (1805, 2835)
# 202_packet_json_new_800/b5_p2_2_0_2.json
# (1651, 2835)
# 202_packet_json_new_800/b4_p1_7_4.json
# (1772, 2835)
# 202_packet_json_new_800/b2_p4_8_1.json
# (1379, 2835)
# 202_packet_json_new_800/b1_p3_6_1.json
# (1313, 2835)
# 202_packet_json_new_800/b3_p5_8_0_2.json
# (1596, 2835)
# 202_packet_json_new_800/b4_p5_5_0_2.json
# (1544, 2835)
# 202_packet_json_new_800/b4_p2_2_0_2.json
# (1657, 2835)
# 202_packet_json_new_800/b5_p1_3_1.json
# (1573, 2835)
# 202_packet_json_new_800/b2_p1_1_1.json
# (1996, 2835)
# 202_packet_json_new_800/b1_p4_3_0_2.json
# (1414, 2835)
# 202_packet_json_new_800/b4_p1_6_1.json
# (1743, 2835)
# 202_packet_json_new_800/b2_p4_7_1.json
# (1632, 2835)
# 202_packet_json_new_800/b3_p2_7_0.json
# (1788, 2835)
# 202_packet_json_new_800/b4_p4_4_0.json
# (1702, 2835)
# 202_packet_json_new_800/b2_p4_8_0.json
# (1736, 2835)
# 202_packet_json_new_800/b1_p5_4_4.json
# (1659, 2835)
# 202_packet_json_new_800/b3_p1_2_1.json
# (1737, 2835)
# 202_packet_json_new_800/b2_p4_6_4.json
# (1670, 2835)
# 202_packet_json_new_800/b2_p1_6_0.json
# (1468, 2835)
# 202_packet_json_new_800/b2_p5_4_0.json
# (1640, 2835)
# 202_packet_json_new_800/b5_p1_4_1.json
# (1692, 2835)
# 202_packet_json_new_800/b3_p1_3_0_2.json
# (1809, 2835)
# 202_packet_json_new_800/b4_p3_1_4.json
# (1740, 2835)
# 202_packet_json_new_800/b4_p1_5_4.json
# (1681, 2835)
# 202_packet_json_new_800/b3_p1_8_4.json
# (1450, 2835)
# 202_packet_json_new_800/b1_p5_7_1.json
# (1531, 2835)
# 202_packet_json_new_800/b3_p2_7_4.json
# (1562, 2835)
# 202_packet_json_new_800/b2_p1_3_0.json
# (1415, 2835)
# 202_packet_json_new_800/b3_p5_7_4.json
# (1433, 2835)
# 202_packet_json_new_800/b5_p2_6_4.json
# (1578, 2835)
# 202_packet_json_new_800/b1_p2_7_0_2.json
# (1465, 2835)
# 202_packet_json_new_800/b3_p2_4_1.json
# (1612, 2835)
# 202_packet_json_new_800/b1_p3_8_1.json
# (1118, 2835)
# 202_packet_json_new_800/b1_p2_3_0.json
# (1575, 2835)
# 202_packet_json_new_800/b5_p2_1_0.json
# (1605, 2835)
# 202_packet_json_new_800/b1_p2_1_0.json
# (1254, 2835)
# 202_packet_json_new_800/b2_p1_2_0.json
# (1620, 2835)
# 202_packet_json_new_800/b2_p5_5_0.json
# (1912, 2835)
# 202_packet_json_new_800/b3_p1_4_4.json
# (1682, 2835)
# 202_packet_json_new_800/b4_p3_8_1.json
# (1553, 2835)
# 202_packet_json_new_800/b2_p2_6_0_2.json
# (1487, 2835)
# 202_packet_json_new_800/b5_p5_1_0.json
# (1642, 2835)
# 202_packet_json_new_800/b2_p2_8_0.json
# (1930, 2835)
# 202_packet_json_new_800/b2_p2_3_0.json
# (1588, 2835)
# 202_packet_json_new_800/b3_p5_4_1.json
# (1704, 2835)
# 202_packet_json_new_800/b3_p2_2_0.json
# (1620, 2835)
# 202_packet_json_new_800/b3_p5_2_4.json
# (1480, 2835)
# 202_packet_json_new_800/b2_p5_6_1.json
# (1806, 2835)
# 202_packet_json_new_800/b2_p2_8_0_2.json
# (1560, 2835)
# 202_packet_json_new_800/b2_p2_7_0.json
# (1619, 2835)
# 202_packet_json_new_800/b4_p3_8_0_2.json
# (1368, 2835)
# 202_packet_json_new_800/b4_p4_2_4.json
# (1701, 2835)
# 202_packet_json_new_800/b4_p3_3_1.json
# (1717, 2835)
# 202_packet_json_new_800/b1_p2_2_1.json
# (1440, 2835)
# 202_packet_json_new_800/b3_p2_5_1.json
# (1524, 2835)
# 202_packet_json_new_800/b2_p3_3_4.json
# (1641, 2835)
# 202_packet_json_new_800/b5_p1_1_4.json
# (2085, 2835)
# 202_packet_json_new_800/b5_p2_6_0.json
# (1593, 2835)
# 202_packet_json_new_800/b3_p1_6_0_2.json
# (1805, 2835)
# 202_packet_json_new_800/b1_p2_3_4.json
# (1396, 2835)
# 202_packet_json_new_800/b5_p2_8_1.json
# (1332, 2835)
# 202_packet_json_new_800/b2_p3_4_4.json
# (1578, 2835)
# 202_packet_json_new_800/b3_p2_4_0.json
# (1818, 2835)
# 202_packet_json_new_800/b1_p2_1_1.json
# (1347, 2835)
# 202_packet_json_new_800/b5_p4_1_0_2.json
# (1440, 2835)
# 202_packet_json_new_800/b3_p4_7_0.json
# (1698, 2835)
# 202_packet_json_new_800/b3_p2_2_4.json
# (1723, 2835)
# 202_packet_json_new_800/b4_p2_7_4.json
# (1759, 2835)
# 202_packet_json_new_800/b4_p1_4_4.json
# (1736, 2835)
# 202_packet_json_new_800/b2_p2_4_0_2.json
# (1556, 2835)
# 202_packet_json_new_800/b1_p4_4_0_2.json
# (1298, 2835)
# 202_packet_json_new_800/b2_p3_5_4.json
# (1576, 2835)
# 202_packet_json_new_800/b5_p4_7_1.json
# (1508, 2835)
# 202_packet_json_new_800/b3_p1_6_4.json
# (1653, 2835)
# 202_packet_json_new_800/b5_p3_8_4.json
# (1411, 2835)
# 202_packet_json_new_800/b1_p2_5_0.json
# (1388, 2835)
# 202_packet_json_new_800/b3_p5_8_0.json
# (1766, 2835)
# 202_packet_json_new_800/b2_p5_7_4.json
# (1579, 2835)
# 202_packet_json_new_800/b3_p5_5_1.json
# (1584, 2835)
# 202_packet_json_new_800/b4_p2_3_0_2.json
# (1649, 2835)
# 202_packet_json_new_800/b4_p5_4_0.json
# (1639, 2835)
# 202_packet_json_new_800/b1_p3_3_1.json
# (1344, 2835)
# 202_packet_json_new_800/b4_p4_2_0_2.json
# (1561, 2835)
# 202_packet_json_new_800/b5_p4_7_0_2.json
# (1486, 2835)
# 202_packet_json_new_800/b5_p3_6_0.json
# (1586, 2835)
# 202_packet_json_new_800/b2_p4_3_0_2.json
# (1627, 2835)
# 202_packet_json_new_800/b3_p3_3_4.json
# (1627, 2835)
# 202_packet_json_new_800/b3_p2_6_4.json
# (1732, 2835)
# 202_packet_json_new_800/b5_p4_5_1.json
# (1580, 2835)
# 202_packet_json_new_800/b1_p1_1_0_2.json
# (1732, 2835)
# 202_packet_json_new_800/b2_p4_2_1.json
# (1742, 2835)
# 202_packet_json_new_800/b2_p4_4_0_2.json
# (1405, 2835)
# 202_packet_json_new_800/b2_p4_2_0_2.json
# (1673, 2835)
# 202_packet_json_new_800/b4_p2_8_1.json
# (1320, 2835)
# 202_packet_json_new_800/b5_p5_3_1.json
# (1731, 2835)
# 202_packet_json_new_800/b2_p3_3_1.json
# (1710, 2835)
# 202_packet_json_new_800/b2_p3_7_1.json
# (1046, 2835)
# 202_packet_json_new_800/b2_p1_4_1.json
# (1837, 2835)
# 202_packet_json_new_800/b5_p2_3_0_2.json
# (1652, 2835)
# 202_packet_json_new_800/b2_p5_8_1.json
# (1531, 2835)
# 202_packet_json_new_800/b4_p2_3_4.json
# (1792, 2835)
# 202_packet_json_new_800/b5_p3_3_1.json
# (1606, 2835)
# 202_packet_json_new_800/b1_p1_5_1.json
# (1414, 2835)
# 202_packet_json_new_800/b4_p3_1_0_2.json
# (1843, 2835)
# 202_packet_json_new_800/b5_p1_6_0_2.json
# (1595, 2835)
# 202_packet_json_new_800/b1_p1_2_4.json
# (1434, 2835)
# 202_packet_json_new_800/b1_p2_8_0_2.json
# (1313, 2835)
# 202_packet_json_new_800/b4_p1_2_1.json
# (1737, 2835)
# 202_packet_json_new_800/b4_p3_6_0_2.json
# (1574, 2835)
# 202_packet_json_new_800/b4_p3_3_0.json
# (1646, 2835)
# 202_packet_json_new_800/b3_p4_4_0.json
# (1821, 2835)
# 202_packet_json_new_800/b4_p1_6_4.json
# (1831, 2835)
# 202_packet_json_new_800/b1_p1_5_4.json
# (1398, 2835)
# 202_packet_json_new_800/b4_p4_7_0.json
# (1738, 2835)
# 202_packet_json_new_800/b5_p1_8_0_2.json
# (1359, 2835)
# 202_packet_json_new_800/b5_p2_5_1.json
# (1557, 2835)
# 202_packet_json_new_800/b3_p2_5_0.json
# (1835, 2835)
# 202_packet_json_new_800/b1_p2_2_0.json
# (1397, 2835)
# 202_packet_json_new_800/b4_p3_2_4.json
# (1621, 2835)
# 202_packet_json_new_800/b3_p4_3_1.json
# (1764, 2835)
# 202_packet_json_new_800/b1_p4_4_0.json
# (1488, 2835)
# 202_packet_json_new_800/b4_p4_3_1.json
# (1620, 2835)
# 202_packet_json_new_800/b1_p2_6_1.json
# (1477, 2835)
# 202_packet_json_new_800/b2_p1_7_0.json
# (1333, 2835)
# 202_packet_json_new_800/b3_p5_8_4.json
# (1504, 2835)
# 202_packet_json_new_800/b1_p5_1_0_2.json
# (1533, 2835)
# 202_packet_json_new_800/b1_p2_4_1.json
# (1448, 2835)
# 202_packet_json_new_800/b3_p2_8_0_2.json
# (1333, 2835)
# 202_packet_json_new_800/b3_p3_6_0_2.json
# (1519, 2835)
# 202_packet_json_new_800/b5_p3_7_4.json
# (1591, 2835)
# 202_packet_json_new_800/b3_p4_3_0_2.json
# (1535, 2835)
# 202_packet_json_new_800/b1_p2_5_4.json
# (1446, 2835)
# 202_packet_json_new_800/b4_p4_5_4.json
# (1531, 2835)
# 202_packet_json_new_800/b1_p4_1_0.json
# (1446, 2835)
# 202_packet_json_new_800/b2_p3_4_0_2.json
# (1627, 2835)
# 202_packet_json_new_800/b1_p5_4_1.json
# (1350, 2835)
# 202_packet_json_new_800/b1_p5_8_1.json
# (1182, 2835)
# 202_packet_json_new_800/b1_p3_5_0_2.json
# (1514, 2835)
# 202_packet_json_new_800/b1_p4_5_0_2.json
# (1408, 2835)
# 202_packet_json_new_800/b4_p3_3_0_2.json
# (1791, 2835)
# 202_packet_json_new_800/b4_p5_7_1.json
# (1589, 2835)
# 202_packet_json_new_800/b4_p5_5_4.json
# (1632, 2835)
# 202_packet_json_new_800/b4_p2_3_1.json
# (1579, 2835)
# 202_packet_json_new_800/b4_p1_2_0.json
# (1569, 2835)
# 202_packet_json_new_800/b3_p1_1_0_2.json
# (1959, 2835)
# 202_packet_json_new_800/b2_p2_8_1.json
# (1483, 2835)
# 202_packet_json_new_800/b5_p3_4_1.json
# (1627, 2835)
# 202_packet_json_new_800/b5_p2_1_4.json
# (1598, 2835)
# 202_packet_json_new_800/b5_p1_8_1.json
# (1432, 2835)
# 202_packet_json_new_800/b1_p1_4_1.json
# (1576, 2835)
# 202_packet_json_new_800/b3_p1_2_4.json
# (1717, 2835)
# 202_packet_json_new_800/b5_p1_7_0_2.json
# (1633, 2835)
# 202_packet_json_new_800/b2_p5_2_0.json
# (1556, 2835)
# 202_packet_json_new_800/b2_p1_3_0_2.json
# (2015, 2835)
# 202_packet_json_new_800/b3_p1_7_0_2.json
# (1676, 2835)
# 202_packet_json_new_800/b4_p5_5_1.json
# (1692, 2835)
# 202_packet_json_new_800/b3_p2_1_0_2.json
# (1952, 2835)
# 202_packet_json_new_800/b2_p3_6_4.json
# (1687, 2835)
# 202_packet_json_new_800/b2_p5_7_0_2.json
# (1533, 2835)
# 202_packet_json_new_800/b2_p2_4_1.json
# (1597, 2835)
# 202_packet_json_new_800/b2_p2_3_0_2.json
# (1753, 2835)
# 202_packet_json_new_800/b3_p4_2_1.json
# (1567, 2835)
# 202_packet_json_new_800/b1_p4_5_0.json
# (1386, 2835)
# 202_packet_json_new_800/b3_p3_6_0.json
# (1692, 2835)
# 202_packet_json_new_800/b2_p5_2_4.json
# (1639, 2835)
# 202_packet_json_new_800/b1_p5_5_4.json
# (1444, 2835)
# 202_packet_json_new_800/b4_p1_1_0_2.json
# (1679, 2835)
# 202_packet_json_new_800/b3_p4_6_0.json
# (2023, 2835)
# 202_packet_json_new_800/b3_p4_8_0.json
# (1279, 2835)
# 202_packet_json_new_800/b4_p1_8_4.json
# (1395, 2835)
# 202_packet_json_new_800/b2_p2_1_4.json
# (2062, 2835)
# 202_packet_json_new_800/b3_p2_8_0.json
# (1574, 2835)
# 202_packet_json_new_800/b2_p3_1_4.json
# (1941, 2835)
# 202_packet_json_new_800/b3_p3_1_4.json
# (1969, 2835)
# 202_packet_json_new_800/b1_p1_3_4.json
# (1562, 2835)
# 202_packet_json_new_800/b4_p4_6_1.json
# (1550, 2835)
# 202_packet_json_new_800/b1_p1_6_1.json
# (1569, 2835)
# 202_packet_json_new_800/b4_p2_7_0_2.json
# (1553, 2835)
# 202_packet_json_new_800/b3_p5_2_1.json
# (2025, 2835)
# 202_packet_json_new_800/b5_p3_6_1.json
# (1683, 2835)
# 202_packet_json_new_800/b4_p2_6_0_2.json
# (1678, 2835)
# 202_packet_json_new_800/b2_p5_6_0_2.json
# (1560, 2835)
# 202_packet_json_new_800/b4_p2_2_1.json
# (1547, 2835)
# 202_packet_json_new_800/b5_p3_4_0_2.json
# (1587, 2835)
# 202_packet_json_new_800/b3_p5_5_0_2.json
# (1770, 2835)
# 202_packet_json_new_800/b1_p4_2_0_2.json
# (1239, 2835)
# 202_packet_json_new_800/b1_p5_5_0.json
# (1394, 2835)
# 202_packet_json_new_800/b1_p3_6_4.json
# (1290, 2835)
# 202_packet_json_new_800/b4_p1_3_1.json
# (1687, 2835)
# 202_packet_json_new_800/b5_p1_2_4.json
# (1539, 2835)
# 202_packet_json_new_800/b3_p4_1_4.json
# (1464, 2835)
# 202_packet_json_new_800/b4_p4_8_1.json
# (1559, 2835)
# 202_packet_json_new_800/b1_p4_2_0.json
# (1796, 2835)
# 202_packet_json_new_800/b3_p4_2_0.json
# (1810, 2835)
# 202_packet_json_new_800/b2_p2_5_1.json
# (1530, 2835)
# 202_packet_json_new_800/b3_p2_3_0.json
# (1674, 2835)
# 202_packet_json_new_800/b2_p5_3_4.json
# (1541, 2835)
# 202_packet_json_new_800/b3_p3_6_4.json
# (1704, 2835)
# 202_packet_json_new_800/b3_p5_1_0_2.json
# (2029, 2835)
# 202_packet_json_new_800/b1_p2_2_4.json
# (1505, 2835)
# 202_packet_json_new_800/b4_p4_5_0_2.json
# (1698, 2835)
# 202_packet_json_new_800/b5_p2_6_0_2.json
# (1548, 2835)
# 202_packet_json_new_800/b2_p2_2_1.json
# (1627, 2835)
# 202_packet_json_new_800/b3_p3_2_0_2.json
# (2130, 2835)
# 202_packet_json_new_800/b3_p2_6_0_2.json
# (1594, 2835)
# 202_packet_json_new_800/b5_p5_8_4.json
# (1463, 2835)
# 202_packet_json_new_800/b4_p1_8_1.json
# (1586, 2835)
# 202_packet_json_new_800/b3_p2_8_4.json
# (1369, 2835)
# 202_packet_json_new_800/b5_p2_8_0_2.json
# (1209, 2835)
# 202_packet_json_new_800/b4_p1_8_0_2.json
# (1314, 2835)
# 202_packet_json_new_800/b1_p5_6_0_2.json
# (1459, 2835)
# 202_packet_json_new_800/b3_p1_3_0.json
# (1569, 2835)
# 202_packet_json_new_800/b1_p3_4_4.json
# (1310, 2835)
# 202_packet_json_new_800/b2_p1_4_0.json
# (1628, 2835)
# 202_packet_json_new_800/b2_p2_8_4.json
# (1619, 2835)
# 202_packet_json_new_800/b5_p5_4_0.json
# (1754, 2835)
# 202_packet_json_new_800/b1_p3_5_1.json
# (1440, 2835)
# 202_packet_json_new_800/b2_p5_5_0_2.json
# (1751, 2835)
# 202_packet_json_new_800/b3_p4_8_1.json
# (1450, 2835)
# 202_packet_json_new_800/b2_p5_8_0_2.json
# (1291, 2835)
# 202_packet_json_new_800/b4_p3_6_4.json
# (1583, 2835)
# 202_packet_json_new_800/b4_p5_6_1.json
# (1752, 2835)
# 202_packet_json_new_800/b2_p5_4_4.json
# (1857, 2835)
# 202_packet_json_new_800/b5_p5_1_1.json
# (1921, 2835)
# 202_packet_json_new_800/b2_p5_4_0_2.json
# (1765, 2835)
# 202_packet_json_new_800/b4_p4_3_0.json
# (1751, 2835)
# 202_packet_json_new_800/b3_p1_1_1.json
# (1688, 2835)
# 202_packet_json_new_800/b2_p4_7_4.json
# (1793, 2835)
# 202_packet_json_new_800/b1_p5_6_1.json
# (1323, 2835)
# 202_packet_json_new_800/b4_p2_8_0_2.json
# (1462, 2835)
# 202_packet_json_new_800/b2_p2_6_0.json
# (1306, 2835)
# 202_packet_json_new_800/b1_p1_1_4.json
# (1697, 2835)
# 202_packet_json_new_800/b4_p4_1_0_2.json
# (1497, 2835)
# 202_packet_json_new_800/b1_p2_8_4.json
# (1327, 2835)
# 202_packet_json_new_800/b4_p5_8_0.json
# (1272, 2835)
# 202_packet_json_new_800/b5_p3_3_0_2.json
# (1576, 2835)
# 202_packet_json_new_800/b4_p4_7_1.json
# (1534, 2835)
# 202_packet_json_new_800/b5_p1_6_0.json
# (1415, 2835)
# 202_packet_json_new_800/b3_p3_3_1.json
# (1600, 2835)
# 202_packet_json_new_800/b5_p5_4_1.json
# (1558, 2835)
# 202_packet_json_new_800/b1_p3_3_0.json
# (1488, 2835)
# 202_packet_json_new_800/b3_p2_4_4.json
# (1753, 2835)
# 202_packet_json_new_800/b1_p3_1_0.json
# (1583, 2835)
# 202_packet_json_new_800/b2_p1_6_0_2.json
# (1927, 2835)
# 202_packet_json_new_800/b3_p2_2_0_2.json
# (1593, 2835)
# 202_packet_json_new_800/b4_p2_5_1.json
# (1578, 2835)
# 202_packet_json_new_800/b5_p1_2_1.json
# (1701, 2835)
# 202_packet_json_new_800/b5_p3_5_1.json
# (1478, 2835)
# 202_packet_json_new_800/b1_p5_2_0.json
# (1539, 2835)
# 202_packet_json_new_800/b2_p4_4_1.json
# (1654, 2835)
# 202_packet_json_new_800/b3_p3_8_0.json
# (1525, 2835)
# 202_packet_json_new_800/b1_p3_7_0_2.json
# (1580, 2835)
# 202_packet_json_new_800/b4_p3_5_1.json
# (1705, 2835)
# 202_packet_json_new_800/b4_p1_4_0_2.json
# (1756, 2835)
# 202_packet_json_new_800/b5_p5_3_0_2.json
# (1787, 2835)
# 202_packet_json_new_800/b5_p3_8_0.json
# (1588, 2835)
# 202_packet_json_new_800/b3_p3_4_4.json
# (1603, 2835)
# 202_packet_json_new_800/b3_p4_1_1.json
# (2277, 2835)
# 202_packet_json_new_800/b3_p4_6_4.json
# (1715, 2835)
# 202_packet_json_new_800/b5_p1_3_0_2.json
# (1643, 2835)
# 202_packet_json_new_800/b5_p4_5_0.json
# (2373, 2835)
# 202_packet_json_new_800/b1_p4_5_1.json
# (1465, 2835)
# 202_packet_json_new_800/b3_p1_4_0.json
# (1865, 2835)
# 202_packet_json_new_800/b2_p4_1_1.json
# (1745, 2835)
# 202_packet_json_new_800/b3_p1_6_1.json
# (1817, 2835)
# 202_packet_json_new_800/b1_p4_8_0.json
# (1450, 2835)
# 202_packet_json_new_800/b5_p5_7_0.json
# (1638, 2835)
# 202_packet_json_new_800/b1_p4_7_1.json
# (1392, 2835)
# 202_packet_json_new_800/b1_p5_1_1.json
# (1435, 2835)
# 202_packet_json_new_800/b5_p2_1_0_2.json
# (1738, 2835)
# 202_packet_json_new_800/b3_p2_8_1.json
# (1292, 2835)
# 202_packet_json_new_800/b3_p5_1_1.json
# (1208, 2835)
# 202_packet_json_new_800/b2_p1_8_0.json
# (1253, 2835)
# 202_packet_json_new_800/b5_p2_2_4.json
# (1640, 2835)
# 202_packet_json_new_800/b3_p3_7_1.json
# (1568, 2835)
# 202_packet_json_new_800/b2_p3_5_0.json
# (1709, 2835)
# 202_packet_json_new_800/b2_p1_2_0_2.json
# (1661, 2835)
# 202_packet_json_new_800/b3_p5_2_0_2.json
# (1621, 2835)
# 202_packet_json_new_800/b1_p4_2_1.json
# (1492, 2835)
# 202_packet_json_new_800/b5_p5_2_1.json
# (1670, 2835)
# 202_packet_json_new_800/b1_p5_3_0_2.json
# (1608, 2835)
# 202_packet_json_new_800/b1_p1_6_4.json
# (1594, 2835)
# 202_packet_json_new_800/b3_p4_3_0.json
# (1627, 2835)
# 202_packet_json_new_800/b2_p2_3_4.json
# (1864, 2835)
# 202_packet_json_new_800/b4_p2_5_0_2.json
# (1502, 2835)
# 202_packet_json_new_800/b2_p2_6_4.json
# (1846, 2835)
# 202_packet_json_new_800/b1_p4_6_4.json
# (1626, 2835)
# 202_packet_json_new_800/b4_p5_1_0.json
# (1596, 2835)
# 202_packet_json_new_800/b5_p4_8_0.json
# (1378, 2835)
# 202_packet_json_new_800/b1_p1_7_0_2.json
# (1450, 2835)
# 202_packet_json_new_800/b2_p1_6_4.json
# (1582, 2835)
# 202_packet_json_new_800/b1_p2_7_4.json
# (1394, 2835)
# 202_packet_json_new_800/b2_p4_6_0.json
# (1694, 2835)
# 202_packet_json_new_800/b4_p2_1_0.json
# (1677, 2835)
# 202_packet_json_new_800/b2_p2_1_0.json
# (2034, 2835)
# 202_packet_json_new_800/b3_p2_7_0_2.json
# (1716, 2835)
# 202_packet_json_new_800/b2_p2_7_1.json
# (1881, 2835)
# 202_packet_json_new_800/b4_p4_3_0_2.json
# (1678, 2835)
# 202_packet_json_new_800/b2_p4_1_0.json
# (1657, 2835)
# 202_packet_json_new_800/b1_p4_3_4.json
# (1399, 2835)
# 202_packet_json_new_800/b1_p2_2_0_2.json
# (1418, 2835)
# 202_packet_json_new_800/b4_p1_5_0.json
# (1676, 2835)
# 202_packet_json_new_800/b5_p2_3_0.json
# (1718, 2835)
# 202_packet_json_new_800/b2_p1_8_0_2.json
# (1456, 2835)
# 202_packet_json_new_800/b5_p3_1_0_2.json
# (1495, 2835)
# 202_packet_json_new_800/b1_p3_3_0_2.json
# (1552, 2835)
# 202_packet_json_new_800/b1_p3_1_0_2.json
# (1502, 2835)
# 202_packet_json_new_800/b5_p3_8_0_2.json
# (1326, 2835)
# 202_packet_json_new_800/b4_p5_2_0.json
# (1601, 2835)
# 202_packet_json_new_800/b4_p2_6_1.json
# (1574, 2835)
# 202_packet_json_new_800/b4_p1_2_4.json
# (1682, 2835)
# 202_packet_json_new_800/b3_p5_6_4.json
# (1572, 2835)
# 202_packet_json_new_800/b4_p3_4_1.json
# (1532, 2835)
# 202_packet_json_new_800/b1_p2_5_1.json
# (1375, 2835)
# 202_packet_json_new_800/b1_p3_3_4.json
# (1479, 2835)
# 202_packet_json_new_800/b4_p1_1_0.json
# (1682, 2835)
# 202_packet_json_new_800/b4_p4_5_0.json
# (1692, 2835)
# 202_packet_json_new_800/b1_p3_8_0_2.json
# (1494, 2835)
# 202_packet_json_new_800/b5_p4_8_0_2.json
# (1283, 2835)
# 202_packet_json_new_800/b1_p2_6_4.json
# (1488, 2835)
# 202_packet_json_new_800/b2_p1_5_0_2.json
# (1723, 2835)
# 202_packet_json_new_800/b2_p5_1_0_2.json
# (1779, 2835)
# 202_packet_json_new_800/b4_p2_6_0.json
# (1478, 2835)
# 202_packet_json_new_800/b3_p2_6_1.json
# (1675, 2835)
# 202_packet_json_new_800/b2_p1_6_1.json
# (1705, 2835)
# 202_packet_json_new_800/b4_p2_3_0.json
# (1547, 2835)
# 202_packet_json_new_800/b1_p5_4_0_2.json
# (1629, 2835)
# 202_packet_json_new_800/b2_p1_7_4.json
# (1690, 2835)
# 202_packet_json_new_800/b4_p5_4_1.json
# (1722, 2835)
# 202_packet_json_new_800/b5_p3_5_4.json
# (1494, 2835)
# 202_packet_json_new_800/b4_p2_8_4.json
# (1462, 2835)
# 202_packet_json_new_800/b5_p3_2_4.json
# (1510, 2835)
# 202_packet_json_new_800/b5_p2_6_1.json
# (1390, 2835)
# 202_packet_json_new_800/b3_p4_2_4.json
# (1010, 2835)
# 202_packet_json_new_800/b2_p4_2_0.json
# (1952, 2835)
# 202_packet_json_new_800/b5_p4_1_0.json
# (1583, 2835)
# 202_packet_json_new_800/b2_p5_1_4.json
# (1519, 2835)
# 202_packet_json_new_800/b3_p4_6_1.json
# (1503, 2835)
# 202_packet_json_new_800/b5_p4_4_0_2.json
# (1660, 2835)
# 202_packet_json_new_800/b4_p5_7_4.json
# (1795, 2835)
# 202_packet_json_new_800/b5_p5_6_0_2.json
# (1642, 2835)
# 202_packet_json_new_800/b4_p2_8_0.json
# (1279, 2835)
# 202_packet_json_new_800/b2_p5_8_4.json
# (1594, 2835)
# 202_packet_json_new_800/b3_p4_5_0_2.json
# (1716, 2835)
# 202_packet_json_new_800/b3_p1_8_0_2.json
# (1449, 2835)
# 202_packet_json_new_800/b5_p3_2_1.json
# (1576, 2835)
# 202_packet_json_new_800/b3_p3_7_0.json
# (1560, 2835)
# 202_packet_json_new_800/b1_p5_7_0.json
# (1480, 2835)
# 202_packet_json_new_800/b5_p2_4_0_2.json
# (1532, 2835)
# 202_packet_json_new_800/b1_p3_7_0.json
# (1588, 2835)
# 202_packet_json_new_800/b2_p3_2_1.json
# (1950, 2835)
# 202_packet_json_new_800/b2_p4_7_0.json
# (1802, 2835)
# 202_packet_json_new_800/b3_p4_1_0_2.json
# (1778, 2835)
# 202_packet_json_new_800/b5_p3_3_4.json
# (1587, 2835)
# 202_packet_json_new_800/b3_p5_6_1.json
# (1557, 2835)
# 202_packet_json_new_800/b1_p1_1_0.json
# (1594, 2835)
# 202_packet_json_new_800/b3_p1_7_0.json
# (1696, 2835)
# 202_packet_json_new_800/b1_p4_6_1.json
# (1452, 2835)
# 202_packet_json_new_800/b4_p5_2_4.json
# (1524, 2835)
# 202_packet_json_new_800/b1_p1_4_4.json
# (1537, 2835)
# 202_packet_json_new_800/b3_p3_7_4.json
# (1675, 2835)
# 202_packet_json_new_800/b1_p3_2_0.json
# (1491, 2835)
# 202_packet_json_new_800/b3_p1_8_1.json
# (1523, 2835)
# 202_packet_json_new_800/b4_p3_8_4.json
# (1468, 2835)
# 202_packet_json_new_800/b3_p2_3_1.json
# (1521, 2835)
# 202_packet_json_new_800/b3_p1_3_4.json
# (1580, 2835)
# 202_packet_json_new_800/b4_p2_1_0_2.json
# (1964, 2835)
# 202_packet_json_new_800/b5_p4_4_1.json
# (1745, 2835)
# 202_packet_json_new_800/b2_p1_1_4.json
# (1639, 2835)
# 202_packet_json_new_800/b3_p4_5_0.json
# (1603, 2835)
# 202_packet_json_new_800/b4_p2_4_0_2.json
# (1650, 2835)
# 202_packet_json_new_800/b4_p5_3_0_2.json
# (1538, 2835)
# 202_packet_json_new_800/b2_p3_1_1.json
# (2522, 2835)
# 202_packet_json_new_800/b1_p5_4_0.json
# (1517, 2835)
# 202_packet_json_new_800/b1_p4_7_4.json
# (1419, 2835)
# 202_packet_json_new_800/b5_p5_2_0_2.json
# (1592, 2835)
# 202_packet_json_new_800/b4_p3_5_4.json
# (1612, 2835)
# 202_packet_json_new_800/b3_p1_6_0.json
# (1547, 2835)
# 202_packet_json_new_800/b5_p4_4_0.json
# (1411, 2835)
# 202_packet_json_new_800/b4_p5_6_0.json
# (1705, 2835)
# 生成了 800 个样本特征
# 第一个样本的特征形状: (1486, 2835)

# %%
from hmmlearn import hmm
import numpy as np
from sklearn.metrics import accuracy_score

# Load features and labels (as previously defined)
# features_list = []
# for data_path in data_paths:
#     features = process_json(data_path)
#     features_list.append(features)

# Flatten features and ensure all have the same shape
if split == 1:
    fixed_time_steps = 3000
elif split == 2:
    fixed_time_steps = 1500
else:
    fixed_time_steps = 12000

target_dim = 256  # 降到 256 维
pca = PCA(n_components=target_dim)

# 对每个特征矩阵进行降维
reduced_features_list = []
for feature in features_list:
    reduced_feature = pca.fit_transform(feature)  # 对特征维度进行降维
    # print(reduced_feature.shape)
    reduced_features_list.append(reduced_feature)

# 截断或补零到固定时间步长

aligned_features = []
for feature in reduced_features_list:
    if feature.shape[0] > fixed_time_steps:
        truncated = feature[:fixed_time_steps, :]
    else:
        truncated = np.pad(feature, ((0, fixed_time_steps - feature.shape[0]), (0, 0)), mode='constant')
    aligned_features.append(truncated)

# 截断或补零到固定时间步长
# aligned_features = []
# for feature in features_list:
#     if feature.shape[0] > fixed_time_steps:
#         truncated = feature[:fixed_time_steps, :]
#     else:
#         truncated = np.pad(feature, ((0, fixed_time_steps - feature.shape[0]), (0, 0)), mode='constant')
#     aligned_features.append(truncated)

# Convert features and labels to NumPy arrays
features_array = np.array(aligned_features)
labels_array = np.array(labels)

# Split the dataset into train and validation sets
if split == 1:
    train_features = features_array[:210]
    train_labels = labels_array[:210]
    eval_features = features_array[210:]
    eval_labels = labels_array[210:]
elif split == 2:
    train_features = features_array[:600]
    train_labels = labels_array[:600]
    eval_features = features_array[600:]
    eval_labels = labels_array[600:]
else:
    train_features = features_array[:70]
    train_labels = labels_array[:70]
    eval_features = features_array[70:]
    eval_labels = labels_array[70:]

# %%
# Train HMM for each class
unique_labels = np.unique(train_labels)
hmm_models = {}

for label in unique_labels:
    # Get features for this label
    label_features = train_features[train_labels == label]
    # Concatenate features to create a single sequence (HMM expects continuous sequences)
    concatenated_features = np.vstack(label_features)
    # Train a Gaussian HMM for this class
    model = hmm.GaussianHMM(n_components=5, covariance_type="diag", n_iter=3000)
    model.fit(concatenated_features)
    hmm_models[label] = model

# Predict function for HMM
def predict_hmm(models, features):
    """Predict the label for a sequence of features using trained HMMs."""
    scores = {}
    for label, model in models.items():
        # Compute the log likelihood of the sequence for each model
        scores[label] = model.score(features)
    # Return the label with the highest score
    return max(scores, key=scores.get)

# Evaluate on the validation set
eval_predictions = []
for feature in eval_features:
    prediction = predict_hmm(hmm_models, feature)
    eval_predictions.append(prediction)

eval_accuracy = accuracy_score(eval_labels, eval_predictions)
print(f"Validation Accuracy: {eval_accuracy * 100:.2f}%")

# Evaluate on the training set (optional)
train_predictions = []
for feature in train_features:
    prediction = predict_hmm(hmm_models, feature)
    train_predictions.append(prediction)

train_accuracy = accuracy_score(train_labels, train_predictions)
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")

# Example usage to predict new samples:
# new_sample = aligned_features[0]
# predicted_label = predict_hmm(hmm_models, new_sample)
# print(f"Predicted class: {predicted_label}")
# Out:
# /home/nesl/anaconda3/envs/202_proj/lib/python3.9/site-packages/hmmlearn/hmm.py:352: RuntimeWarning: invalid value encountered in divide
#   self.means_ = ((means_weight * means_prior + stats['obs'])
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 12
#      10     # Train a Gaussian HMM for this class
#      11     model = hmm.GaussianHMM(n_components=5, covariance_type="diag", n_iter=4000)
# ---> 12     model.fit(concatenated_features)
#      13     hmm_models[label] = model
#      15 # Predict function for HMM
#
# File ~/anaconda3/envs/202_proj/lib/python3.9/site-packages/hmmlearn/base.py:485, in _AbstractHMM.fit(self, X, lengths)
#     482 self.monitor_._reset()
#     484 for iter in range(self.n_iter):
# --> 485     stats, curr_logprob = self._do_estep(X, lengths)
#     487     # Compute lower bound before updating model parameters
#     488     lower_bound = self._compute_lower_bound(curr_logprob)
#
# File ~/anaconda3/envs/202_proj/lib/python3.9/site-packages/hmmlearn/base.py:764, in _AbstractHMM._do_estep(self, X, lengths)
#     762 curr_logprob = 0
#     763 for sub_X in _utils.split_X_lengths(X, lengths):
# --> 764     lattice, logprob, posteriors, fwdlattice, bwdlattice = impl(sub_X)
#     765     # Derived HMM classes will implement the following method to
#     766     # update their probability distributions, so keep
#     767     # a single call to this method for simplicity.
#     768     self._accumulate_sufficient_statistics(
#     769         stats, sub_X, lattice, posteriors, fwdlattice,
#     770         bwdlattice)
#
# File ~/anaconda3/envs/202_proj/lib/python3.9/site-packages/hmmlearn/base.py:883, in BaseHMM._fit_log(self, X)
#     882 def _fit_log(self, X):
# --> 883     log_frameprob = self._compute_log_likelihood(X)
#     884     log_prob, fwdlattice = _hmmc.forward_log(
#     885         self.startprob_, self.transmat_, log_frameprob)
#     886     bwdlattice = _hmmc.backward_log(
#     887         self.startprob_, self.transmat_, log_frameprob)
#
# File ~/anaconda3/envs/202_proj/lib/python3.9/site-packages/hmmlearn/_emissions.py:130, in BaseGaussianHMM._compute_log_likelihood(self, X)
#     129 def _compute_log_likelihood(self, X):
# --> 130     return log_multivariate_normal_density(
#     131         X, self.means_, self._covars_, self.covariance_type)
#
# File ~/anaconda3/envs/202_proj/lib/python3.9/site-packages/hmmlearn/stats.py:42, in log_multivariate_normal_density(X, means, covars, covariance_type)
#       6 """
#       7 Compute the log probability under a multivariate Gaussian distribution.
#       8
#    (...)
#      35     X under each of the n_components multivariate Gaussian distributions.
#      36 """
#      37 log_multivariate_normal_density_dict = {
#      38     'spherical': _log_multivariate_normal_density_spherical,
#      39     'tied': _log_multivariate_normal_density_tied,
#      40     'diag': _log_multivariate_normal_density_diag,
#      41     'full': _log_multivariate_normal_density_full}
# ---> 42 return log_multivariate_normal_density_dict[covariance_type](
#      43     X, means, covars
#      44 )
#
# File ~/anaconda3/envs/202_proj/lib/python3.9/site-packages/hmmlearn/stats.py:56, in _log_multivariate_normal_density_diag(X, means, covars)
#      52 covars = np.maximum(covars, np.finfo(float).tiny)
#      53 with np.errstate(over="ignore"):
#      54     return -0.5 * (nf * np.log(2 * np.pi)
#      55                    + np.log(covars).sum(axis=-1)
# ---> 56                    + ((X[:, None, :] - means) ** 2 / covars).sum(axis=-1))
#
# File ~/anaconda3/envs/202_proj/lib/python3.9/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:
